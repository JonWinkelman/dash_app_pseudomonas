# %%
import sys
import inspect
from jw_utils import jw_draw_tree as jdt
from ete3 import ncbi_taxonomy
from ete3 import Tree
ncbi_tax = ncbi_taxonomy.NCBITaxa()
import json
from jw_utils import ncbi_datasets_fxs as nfx
from orthofinder_utils import dash_ortho_parser_d as dop
from Bio import Phylo
from plotly import graph_objects as go
from jw_utils import jw_ncbi_taxonomy as jnt
import os

# %%
sp_tree_path = './data/Species_Tree/SpeciesTree_rooted_node_labels.txt'
path_to_summary ='./data/summary_data/summaries.json'

# %%
def accession_taxid_d(path_to_summary):
    """Return simplified dict {acc:taxid} from ncbi summary.json."""
    
    with open(path_to_summary, 'r') as f:
        summary_d = nfx.make_summary_dict(json.load(f))
    acc_tax_d ={}
    for acc in summary_d:
        acc_tax_d[acc] = summary_d[acc]['org']['tax_id']
    return acc_tax_d



def get_rank_sciname_for_each_leaf(tree, rank, path_to_summary):
    """Return a dict with a sci_name at a given rank for each leaf {leaf:sci_name}
    e.g. given rank phylum: return {GCF_######:'Proteobacteria'}
    """

    acc_tax_d =  accession_taxid_d(path_to_summary)   
    leaf_rank_sciname = {}
    for leaf in tree.get_terminals():
        leaf_taxid = acc_tax_d[leaf.name]
        leaf_rank_taxid = jnt.get_lineage_rank_dict(leaf_taxid).get(rank)
        if leaf_rank_taxid:
            leaf_rank_sciname[leaf.name] = list(ncbi_tax.get_taxid_translator([leaf_rank_taxid]).values())[0]
        else:
            leaf_rank_sciname[leaf.name] = None
    return leaf_rank_sciname



def get_list_of_all_nodes(subtree, clades=None):
    """Get a list of all clade objects, including leaves, in a Bio.Phylo tree"""
    if not isinstance(subtree, (Phylo.Newick.Tree, Phylo.Newick.Clade)):
        raise TypeError(f'object entered needs to be of type {Phylo.Newick.Tree} or {Phylo.Newick.Clade}, you entered {type(subtree)}' )
        
    if clades is None:
        clades=[]
    for cl in subtree.root:
        clades.append(cl)
        if cl.is_terminal():
             clades.append(cl)
        else:
            get_list_of_all_nodes(cl, clades)
    return clades



def get_nodes_assoc_with_ranks(tree, rank, path_to_summary):
    """"""
    leaf_rank_scinames_d = get_rank_sciname_for_each_leaf(tree, rank, path_to_summary)
    node_dict = {}
    for cl in get_list_of_all_nodes(tree):
        #check to see if all leaves in clade have same sci_name, if so then clade is that sci_name
        leaves =  cl.get_terminals()
        sci_names = []

        for leaf in leaves:
            sci_names.append(leaf_rank_scinames_d[leaf.name])
        sci_names = list(set(sci_names))
        if len(sci_names) == 1:
            node_dict[cl.name] = sci_names[0]
    unique_scinames = set(list(node_dict.values()))
    rank_nodes = {n:[] for n in unique_scinames}
    for node, sci_name in node_dict.items():
        rank_nodes[sci_name].append(node)
    return rank_nodes


def get_anc_node_each_rank(tree, rank, path_to_summary):
    """"""
    rank_nodes = get_nodes_assoc_with_ranks(tree, rank, path_to_summary)
    mrca_clades = {}
    for rank_name, clades in rank_nodes.items():
        leaves = []
        for cl in clades:
            clade = tree.find_any(cl) 
            if clade.is_terminal():
                leaves.append(clade)
        mrca_clade  = tree.is_monophyletic(leaves)
        if mrca_clade:
            mrca_clades[rank_name] = mrca_clade.name
        else:
            mrca_clades[rank_name] = 'not monophyletic'
    return mrca_clades

# %%
tree = Phylo.read(sp_tree_path, format='newick')
rank='class'
all_clades = get_list_of_all_nodes(tree)
    
mrca_clades = get_anc_node_each_rank(tree, 'phylum', path_to_summary)

def make_mrcaClade_file(tree, path_to_summary):
    rank_mrca_clades_d = {}
    available_ranks = ['no rank', 'superkingdom','family', 'genus', 'phylum', 'class', 'order', 'species']
    for rank in available_ranks:
        mrca_clades = get_anc_node_each_rank(tree, rank, path_to_summary)
        rank_mrca_clades_d[rank] = mrca_clades
    with open('./ranks_mrca_clades.json', 'w') as f:
        json.dump(rank_mrca_clades_d, f)
    return rank_mrca_clades_d  

make_mrcaClade_file(tree, path_to_summary)
# Out:
# {'no rank': {'Pseudomonas amygdali pv. aesculi': 'GCF_001400675.1',
#   'Pseudomonas syringae pv. helianthi': 'GCF_022557235.1',
#   'Pseudomonas amygdali pv. loropetali': 'GCF_023207855.1',
#   'Pseudomonas coronafaciens pv. coronafaciens': 'GCF_003699955.1',
#   'Pseudomonas syringae pv. lapsa': 'N201',
#   'Pseudomonas savastanoi pv. savastanoi': 'N183',
#   'unclassified Pseudomonas': 'not monophyletic',
#   'Pseudomonas syringae group pathovars incertae sedis': 'N130',
#   'cellular organisms': 'not monophyletic',
#   'Pseudomonas cannabina pv. alisalensis': 'GCF_016599635.1',
#   'Pseudomonas syringae pv. atrofaciens': 'GCF_003047185.1'},
#  'superkingdom': {'Bacteria': 'N0'},
#  'family': {'Moraxellaceae': 'N2',
#   'Pseudomonadaceae': 'N3',
#   'Burkholderiaceae': 'GCF_002362295.1'},
#  'genus': {'Acinetobacter': 'N2',
#   'Halopseudomonas': 'not monophyletic',
#   'Burkholderia': 'GCF_002362295.1',
#   'Stutzerimonas': 'not monophyletic',
#   'Pseudomonas': 'not monophyletic'},
#  'phylum': {'Pseudomonadota': 'N0'},
#  'class': {'Betaproteobacteria': 'GCF_002362295.1',
#   'Gammaproteobacteria': 'N1'},
#  'order': {'Burkholderiales': 'GCF_002362295.1',
#   'Pseudomonadales': 'N3',
#   'Moraxellales': 'N2'},
#  'species': {'Pseudomonas parafulva': 'GCF_001477425.1',
#   'Pseudomonas chlororaphis': 'N122',
#   'Pseudomonas protegens': 'N153',
#   'Pseudomonas koreensis': 'GCF_001605965.1',
#   'Pseudomonas phenolilytica': 'GCF_021432765.1',
#   'Pseudomonas viridiflava': 'not monophyletic',
#   'Pseudomonas arsenicoxydans': 'GCF_004135995.1',
#   'Pseudomonas sp. ATCC 13867': 'GCF_000349845.1',
#   'Pseudomonas prosekii': 'GCF_003671865.1',
#   'Pseudomonas fragi': 'GCF_015476275.1',
#   'Pseudomonas extremorientalis': 'GCF_008801565.1',
#   'Halopseudomonas salegens': 'GCF_900105655.1',
#   'Halopseudomonas litoralis': 'GCF_900105005.1',
#   'Pseudomonas sp. FW305-17': 'GCF_002884415.1',
#   'Pseudomonas tritici': 'GCF_014268275.2',
#   'Pseudomonas juntendi': 'GCF_021725455.1',
#   'Pseudomonas granadensis': 'GCF_900105485.1',
#   'Pseudomonas corrugata': 'GCF_001708425.1',
#   'Stutzerimonas stutzeri': 'not monophyletic',
#   'Pseudomonas chengduensis': 'N107',
#   'Pseudomonas cremoricolorata': 'GCF_000759535.1',
#   'Pseudomonas syringae group genomosp. 3': 'not monophyletic',
#   'Pseudomonas plecoglossicida': 'GCF_002864795.1',
#   'Pseudomonas shahriarae': 'GCF_014268455.2',
#   'Pseudomonas vanderleydeniana': 'GCF_014268755.2',
#   'Pseudomonas migulae': 'GCF_014076455.1',
#   'Burkholderia ubonensis': 'GCF_002362295.1',
#   'Pseudomonas extremaustralis': 'GCF_900625045.1',
#   'Pseudomonas pohangensis': 'GCF_900105995.1',
#   'Pseudomonas mendocina': 'not monophyletic',
#   'Pseudomonas azerbaijanoriens': 'GCF_019139795.1',
#   'Pseudomonas cannabina': 'GCF_016599635.1',
#   'Pseudomonas coronafaciens': 'N113',
#   'Pseudomonas rhodesiae': 'GCF_018417575.1',
#   'Pseudomonas knackmussii': 'GCF_009911755.1',
#   'Halopseudomonas pelagia': 'GCF_009497895.1',
#   'Pseudomonas syringae': 'not monophyletic',
#   '[Pseudomonas] zhaodongensis': 'GCF_024448735.1',
#   'Pseudomonas kermanshahensis': 'GCF_024023035.1',
#   'Acinetobacter colistiniresistens': 'GCF_000413935.1',
#   'Pseudomonas monsensis': 'GCF_014268495.1',
#   'Pseudomonas mosselii': 'GCF_002736065.1',
#   'Pseudomonas oleovorans': 'not monophyletic',
#   'Pseudomonas nitroreducens': 'GCF_900188285.1',
#   'Pseudomonas donghuensis': 'GCF_000696345.2',
#   'Pseudomonas lundensis': 'GCF_001020725.2',
#   'Pseudomonas allokribbensis': 'GCF_014863605.1',
#   'Pseudomonas sediminis': 'GCF_013409125.2',
#   'Pseudomonas brassicacearum': 'N217',
#   'Acinetobacter baumannii': 'GCA_001077675.1',
#   'Pseudomonas psychrotolerans': 'GCF_014522265.1',
#   'Pseudomonas libanensis': 'GCF_001297075.1',
#   'Pseudomonas sivasensis': 'GCF_013778535.1',
#   'Pseudomonas avellanae': 'GCF_002905795.1',
#   'Pseudomonas zeae': 'GCF_014268485.2',
#   'Pseudomonas luteola': 'GCF_008693965.1',
#   'Pseudomonas aeruginosa': 'N36',
#   'Pseudomonas promysalinigenes': 'GCF_014269025.1',
#   'Pseudomonas otitidis': 'N40',
#   'Pseudomonas syringae group genomosp. 7': 'not monophyletic',
#   'Pseudomonas salmasensis': 'GCF_014268375.2',
#   'Pseudomonas mediterranea': 'GCF_001412045.1',
#   'Pseudomonas moraviensis': 'GCF_002287865.1',
#   'Pseudomonas monteilii': 'GCF_000510285.1',
#   'Halopseudomonas sabulinigri': 'GCF_900105255.1',
#   'Acinetobacter nosocomialis': 'GCF_005281455.1',
#   'Acinetobacter baylyi': 'GCF_000046845.1',
#   'Pseudomonas tohonis': 'GCF_021605025.1',
#   'Pseudomonas congelans': 'GCF_002318885.1',
#   'Pseudomonas umsongensis': 'GCF_014190825.1',
#   'Pseudomonas veronii': 'GCF_021233455.1',
#   'Pseudomonas nanhaiensis': 'GCF_020025155.1',
#   'Pseudomonas sp. DR 5-09': 'GCF_001655595.1',
#   'Pseudomonas alkylphenolica': 'N69',
#   'Pseudomonas lurida': 'GCF_002966835.1',
#   'Pseudomonas brenneri': 'GCF_001641345.1',
#   'Pseudomonas qingdaonensis': 'GCF_021601925.1',
#   'Pseudomonas guangdongensis': 'GCF_900105885.1',
#   'Pseudomonas lini': 'GCF_001042905.1',
#   'Pseudomonas fuscovaginae': 'GCF_000280575.1',
#   'Pseudomonas siliginis': 'GCF_024072295.1',
#   'Pseudomonas sihuiensis': 'GCF_900106015.1',
#   'Pseudomonas rhizosphaerae': 'GCF_000761155.1',
#   'Pseudomonas sp. GR 6-02': 'GCF_001655615.1',
#   'Pseudomonas cedrina': 'GCF_900104915.1',
#   'Pseudomonas asturiensis': 'GCF_000452745.2',
#   'Pseudomonas antarctica': 'GCF_001647715.1',
#   'Pseudomonas savastanoi': 'not monophyletic',
#   'Pseudomonas tensinigenes': 'GCF_014268445.1',
#   'Pseudomonas palleroniana': 'GCF_022870785.1',
#   'Halopseudomonas xinjiangensis': 'GCF_900104945.1',
#   'Pseudomonas hamedanensis': 'GCF_014268595.1',
#   'Pseudomonas synxantha': 'not monophyletic',
#   'Pseudomonas campi': 'GCF_013200955.1',
#   'Pseudomonas vancouverensis': 'GCF_004348895.1',
#   'Pseudomonas taiwanensis': 'GCF_013393345.1',
#   'Pseudomonas germanica': 'GCF_019614655.1',
#   'Pseudomonas mucidolens': 'GCF_900106045.1',
#   'Pseudomonas amygdali': 'not monophyletic',
#   'Pseudomonas khazarica': 'GCF_017915135.1',
#   'Pseudomonas fulva': 'N126',
#   'Pseudomonas fluorescens': 'not monophyletic',
#   'Pseudomonas gozinkensis': 'GCF_014863585.1',
#   'Pseudomonas frederiksbergensis': 'GCF_002355315.1',
#   'Pseudomonas bijieensis': 'GCF_013347965.1',
#   'Acinetobacter gyllenbergii': 'GCF_001682515.1',
#   'Pseudomonas taetrolens': 'GCF_900475285.1',
#   'Pseudomonas argentinensis': 'GCF_001839655.2',
#   'Pseudomonas anuradhapurensis': 'GCF_014269225.2',
#   'Pseudomonas asgharzadehiana': 'GCF_019139815.1',
#   'Pseudomonas lalkuanensis': 'GCF_020422905.1',
#   'Pseudomonas atacamensis': 'GCF_017167965.1',
#   'Pseudomonas cerasi': 'GCF_900235895.1',
#   'Pseudomonas fakonensis': 'GCF_019139895.1',
#   'Pseudomonas zarinae': 'GCF_014268695.2',
#   'Pseudomonas tolaasii': 'GCF_019285655.1',
#   'Pseudomonas trivialis': 'GCF_001730655.1',
#   'Stutzerimonas xanthomarina': 'GCF_000825645.2',
#   'Pseudomonas marincola': 'N59',
#   'Pseudomonas benzenivorans': 'GCF_024397895.1',
#   'Pseudomonas toyotomiensis': 'GCF_002741095.1',
#   'Pseudomonas agarici': 'GCF_001543125.1',
#   'Pseudomonas yamanorum': 'GCF_013403585.1',
#   'Pseudomonas azotoformans': 'N216',
#   'Pseudomonas wenzhouensis': 'GCF_021029445.1',
#   'Pseudomonas orientalis': 'GCF_022807995.1',
#   'Pseudomonas xantholysinigenes': 'GCF_014268885.2',
#   'Pseudomonas poae': 'GCF_002980135.1',
#   'Pseudomonas oryzihabitans': 'GCF_001518815.1',
#   'Pseudomonas putida': 'not monophyletic',
#   'Pseudomonas tremae': 'GCF_024413275.1',
#   'Pseudomonas multiresinivorans': 'GCF_012971725.1',
#   'Pseudomonas shirazica': 'GCF_022049085.1',
#   'Pseudomonas sp. Os17': 'GCF_001547895.1',
#   'Candidatus Pseudomonas adelgestsugas': 'GCF_004124255.1',
#   'Pseudomonas mandelii': 'N224',
#   'Pseudomonas sp. St29': 'GCF_001547915.1',
#   'Pseudomonas oryziphila': 'GCF_003940825.1',
#   'Pseudomonas hydrolytica': 'GCF_021495345.1',
#   'Pseudomonas citronellolis': 'GCF_004745455.1',
#   'Pseudomonas iranensis': 'GCF_014268585.2',
#   'Pseudomonas alvandae': 'GCF_019141525.1',
#   'Pseudomonas cichorii': 'GCF_003415775.1',
#   'Pseudomonas eucalypticola': 'GCF_013374995.1',
#   'Pseudomonas entomophila': 'N125',
#   'Pseudomonas kribbensis': 'GCF_021398855.1',
#   'Stutzerimonas degradans': 'GCF_009740185.1',
#   'Pseudomonas xanthosomae': 'GCF_019139835.1',
#   'Pseudomonas muyukensis': 'GCF_019139535.1',
#   'Pseudomonas simiae': 'GCF_016134935.1',
#   'Pseudomonas silesiensis': 'GCF_001661075.1',
#   'Pseudomonas asiatica': 'GCF_014656565.1',
#   'Pseudomonas sp. JY-Q': 'GCF_001655295.1',
#   'Pseudomonas thivervalensis': 'GCF_001269655.1',
#   'Pseudomonas alcaligenes': 'N37',
#   'Pseudomonas maumuensis': 'GCF_019139675.1',
#   'Pseudomonas sessilinigenes': 'GCF_019139855.1',
#   'Pseudomonas oryzae': 'GCF_900104805.1',
#   'Pseudomonas sp. TCU-HL1': 'GCF_001708505.1',
#   'Pseudomonas reinekei': 'GCF_008801455.1',
#   'Pseudomonas izuensis': 'GCF_002356535.2',
#   'Pseudomonas glycinae': 'not monophyletic',
#   'Pseudomonas psychrophila': 'GCF_011040435.1'}}

# %%
def read_mrca_file():
    with open('./ranks_mrca_clades.json', 'r') as f:
        return json.load(f)
rank_mrca_clades_d = read_mrca_file()
rank_mrca_clades_dget_terminals
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       2     with open('./ranks_mrca_clades.json', 'r') as f:
#       3         return json.load(f)
# ----> 4 rank_mrca_clades_d = read_mrca_file()
#       5 rank_mrca_clades_dget_terminals
#
# Cell In[5], line 2, in read_mrca_file()
#       1 def read_mrca_file():
# ----> 2     with open('./ranks_mrca_clades.json', 'r') as f:
#       3         return json.load(f)
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './ranks_mrca_clades.json'

# %%
def make_internal_node_d(tree):
    """"""
internal_node_dict = {}
for node in tree.get_nonterminals():
    internal_node_dict[node.name] = {'name':node.name, 'rank':'', 'taxid':'', 'sci_name':''}
for node in tree.get_terminals():
        internal_node_dict[node.name] = {'name':node.name}
internal_node_dict

with open('./data/summary_data/internal_node_dict.json', 'w') as f:
    json.dump(internal_node_dict, f)
internal_node_dict
# Out:
# {'N0': {'name': 'N0', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N1': {'name': 'N1', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N3': {'name': 'N3', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N7': {'name': 'N7', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N15': {'name': 'N15', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N22': {'name': 'N22', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N30': {'name': 'N30', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N8': {'name': 'N8', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N16': {'name': 'N16', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N23': {'name': 'N23', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N4': {'name': 'N4', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N9': {'name': 'N9', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N17': {'name': 'N17', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N24': {'name': 'N24', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N31': {'name': 'N31', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N39': {'name': 'N39', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N48': {'name': 'N48', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N32': {'name': 'N32', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N10': {'name': 'N10', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N18': {'name': 'N18', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N25': {'name': 'N25', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N26': {'name': 'N26', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N33': {'name': 'N33', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N40': {'name': 'N40', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N49': {'name': 'N49', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N34': {'name': 'N34', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N41': {'name': 'N41', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N42': {'name': 'N42', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N50': {'name': 'N50', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N59': {'name': 'N59', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N2': {'name': 'N2', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N5': {'name': 'N5', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N11': {'name': 'N11', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N19': {'name': 'N19', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N12': {'name': 'N12', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N20': {'name': 'N20', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N27': {'name': 'N27', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N6': {'name': 'N6', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N13': {'name': 'N13', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N14': {'name': 'N14', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N21': {'name': 'N21', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N28': {'name': 'N28', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N35': {'name': 'N35', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N36': {'name': 'N36', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N43': {'name': 'N43', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N51': {'name': 'N51', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N60': {'name': 'N60', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N69': {'name': 'N69', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N83': {'name': 'N83', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N61': {'name': 'N61', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N70': {'name': 'N70', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N71': {'name': 'N71', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N84': {'name': 'N84', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N85': {'name': 'N85', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N102': {'name': 'N102', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N103': {'name': 'N103', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N125': {'name': 'N125', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N126': {'name': 'N126', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N155': {'name': 'N155', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N183': {'name': 'N183', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N205': {'name': 'N205', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N52': {'name': 'N52', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N62': {'name': 'N62', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N72': {'name': 'N72', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N63': {'name': 'N63', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N73': {'name': 'N73', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N86': {'name': 'N86', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N104': {'name': 'N104', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N127': {'name': 'N127', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N156': {'name': 'N156', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N184': {'name': 'N184', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N206': {'name': 'N206', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N105': {'name': 'N105', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N128': {'name': 'N128', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N157': {'name': 'N157', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N129': {'name': 'N129', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N87': {'name': 'N87', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N106': {'name': 'N106', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N130': {'name': 'N130', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N107': {'name': 'N107', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N131': {'name': 'N131', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N74': {'name': 'N74', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N88': {'name': 'N88', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N108': {'name': 'N108', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N89': {'name': 'N89', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N109': {'name': 'N109', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N132': {'name': 'N132', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N158': {'name': 'N158', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N133': {'name': 'N133', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N159': {'name': 'N159', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N185': {'name': 'N185', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N207': {'name': 'N207', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N208': {'name': 'N208', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N219': {'name': 'N219', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N160': {'name': 'N160', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N186': {'name': 'N186', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N209': {'name': 'N209', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N220': {'name': 'N220', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N221': {'name': 'N221', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N110': {'name': 'N110', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N134': {'name': 'N134', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N161': {'name': 'N161', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N162': {'name': 'N162', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N187': {'name': 'N187', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N188': {'name': 'N188', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N210': {'name': 'N210', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N44': {'name': 'N44', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N53': {'name': 'N53', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N64': {'name': 'N64', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N75': {'name': 'N75', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N54': {'name': 'N54', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N65': {'name': 'N65', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N76': {'name': 'N76', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N90': {'name': 'N90', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N111': {'name': 'N111', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N135': {'name': 'N135', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N136': {'name': 'N136', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N163': {'name': 'N163', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N164': {'name': 'N164', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N189': {'name': 'N189', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N190': {'name': 'N190', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N91': {'name': 'N91', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N77': {'name': 'N77', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N92': {'name': 'N92', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N93': {'name': 'N93', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N112': {'name': 'N112', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N137': {'name': 'N137', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N165': {'name': 'N165', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N191': {'name': 'N191', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N138': {'name': 'N138', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N166': {'name': 'N166', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N192': {'name': 'N192', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N167': {'name': 'N167', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N193': {'name': 'N193', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N211': {'name': 'N211', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N222': {'name': 'N222', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N29': {'name': 'N29', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N37': {'name': 'N37', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N45': {'name': 'N45', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N55': {'name': 'N55', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N38': {'name': 'N38', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N46': {'name': 'N46', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N56': {'name': 'N56', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N47': {'name': 'N47', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N57': {'name': 'N57', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N66': {'name': 'N66', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N78': {'name': 'N78', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N94': {'name': 'N94', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N113': {'name': 'N113', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N79': {'name': 'N79', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N95': {'name': 'N95', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N114': {'name': 'N114', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N96': {'name': 'N96', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N115': {'name': 'N115', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N139': {'name': 'N139', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N140': {'name': 'N140', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N168': {'name': 'N168', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N194': {'name': 'N194', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N116': {'name': 'N116', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N141': {'name': 'N141', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N142': {'name': 'N142', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N143': {'name': 'N143', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N144': {'name': 'N144', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N169': {'name': 'N169', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N195': {'name': 'N195', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N212': {'name': 'N212', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N170': {'name': 'N170', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N145': {'name': 'N145', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N171': {'name': 'N171', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N196': {'name': 'N196', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N172': {'name': 'N172', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N58': {'name': 'N58', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N67': {'name': 'N67', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N80': {'name': 'N80', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N97': {'name': 'N97', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N117': {'name': 'N117', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N118': {'name': 'N118', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N146': {'name': 'N146', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N81': {'name': 'N81', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N98': {'name': 'N98', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N119': {'name': 'N119', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N147': {'name': 'N147', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N148': {'name': 'N148', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N173': {'name': 'N173', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N99': {'name': 'N99', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N120': {'name': 'N120', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N149': {'name': 'N149', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N68': {'name': 'N68', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N82': {'name': 'N82', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N100': {'name': 'N100', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N121': {'name': 'N121', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N122': {'name': 'N122', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N150': {'name': 'N150', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N174': {'name': 'N174', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N175': {'name': 'N175', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N197': {'name': 'N197', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N213': {'name': 'N213', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N223': {'name': 'N223', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N227': {'name': 'N227', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N101': {'name': 'N101', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N123': {'name': 'N123', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N151': {'name': 'N151', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N176': {'name': 'N176', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N177': {'name': 'N177', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N152': {'name': 'N152', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N178': {'name': 'N178', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N198': {'name': 'N198', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N199': {'name': 'N199', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N214': {'name': 'N214', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N224': {'name': 'N224', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N179': {'name': 'N179', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N200': {'name': 'N200', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N215': {'name': 'N215', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N124': {'name': 'N124', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N153': {'name': 'N153', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N180': {'name': 'N180', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N201': {'name': 'N201', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N216': {'name': 'N216', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N225': {'name': 'N225', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N154': {'name': 'N154', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N181': {'name': 'N181', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N202': {'name': 'N202', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N182': {'name': 'N182', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N203': {'name': 'N203', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N217': {'name': 'N217', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N204': {'name': 'N204', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N218': {'name': 'N218', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N226': {'name': 'N226', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N228': {'name': 'N228', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'N229': {'name': 'N229', 'rank': '', 'taxid': '', 'sci_name': ''},
#  'GCF_003700835.1': {'name': 'GCF_003700835.1'},
#  'GCF_002966555.1': {'name': 'GCF_002966555.1'},
#  'GCF_000172895.1': {'name': 'GCF_000172895.1'},
#  'GCF_000145885.1': {'name': 'GCF_000145885.1'},
#  'GCF_000007805.1': {'name': 'GCF_000007805.1'},
#  'GCF_009903285.1': {'name': 'GCF_009903285.1'},
#  'GCF_002024285.1': {'name': 'GCF_002024285.1'},
#  'GCF_000344475.3': {'name': 'GCF_000344475.3'},
#  'GCF_002905795.1': {'name': 'GCF_002905795.1'},
#  'GCF_002318885.1': {'name': 'GCF_002318885.1'},
#  'GCF_900235895.1': {'name': 'GCF_900235895.1'},
#  'GCF_003047185.1': {'name': 'GCF_003047185.1'},
#  'GCF_001482725.1': {'name': 'GCF_001482725.1'},
#  'GCF_001400495.1': {'name': 'GCF_001400495.1'},
#  'GCF_000452445.2': {'name': 'GCF_000452445.2'},
#  'GCF_022510205.1': {'name': 'GCF_022510205.1'},
#  'GCF_000988485.1': {'name': 'GCF_000988485.1'},
#  'GCF_022557235.1': {'name': 'GCF_022557235.1'},
#  'GCF_020917325.1': {'name': 'GCF_020917325.1'},
#  'GCF_019334485.1': {'name': 'GCF_019334485.1'},
#  'GCF_023207855.1': {'name': 'GCF_023207855.1'},
#  'GCF_022026035.1': {'name': 'GCF_022026035.1'},
#  'GCF_013911125.1': {'name': 'GCF_013911125.1'},
#  'GCF_000164015.3': {'name': 'GCF_000164015.3'},
#  'GCF_001400675.1': {'name': 'GCF_001400675.1'},
#  'GCF_003413075.1': {'name': 'GCF_003413075.1'},
#  'GCF_020204845.1': {'name': 'GCF_020204845.1'},
#  'GCF_000146005.2': {'name': 'GCF_000146005.2'},
#  'GCF_003699405.1': {'name': 'GCF_003699405.1'},
#  'GCF_014855475.1': {'name': 'GCF_014855475.1'},
#  'GCF_003699955.1': {'name': 'GCF_003699955.1'},
#  'GCF_011765175.1': {'name': 'GCF_011765175.1'},
#  'GCF_024413275.1': {'name': 'GCF_024413275.1'},
#  'GCF_000145845.2': {'name': 'GCF_000145845.2'},
#  'GCF_000145845.1': {'name': 'GCF_000145845.1'},
#  'GCF_016599635.1': {'name': 'GCF_016599635.1'},
#  'GCF_000452705.1': {'name': 'GCF_000452705.1'},
#  'GCF_000452745.2': {'name': 'GCF_000452745.2'},
#  'GCF_018388545.1': {'name': 'GCF_018388545.1'},
#  'GCF_003415775.1': {'name': 'GCF_003415775.1'},
#  'GCF_013374995.1': {'name': 'GCF_013374995.1'},
#  'GCF_000761155.1': {'name': 'GCF_000761155.1'},
#  'GCF_001839655.2': {'name': 'GCF_001839655.2'},
#  'GCF_900682675.1': {'name': 'GCF_900682675.1'},
#  'GCF_900116605.1': {'name': 'GCF_900116605.1'},
#  'GCF_024397895.1': {'name': 'GCF_024397895.1'},
#  'GCF_900626055.1': {'name': 'GCF_900626055.1'},
#  'GCF_017915135.1': {'name': 'GCF_017915135.1'},
#  'GCF_021495345.1': {'name': 'GCF_021495345.1'},
#  'GCF_002442555.1': {'name': 'GCF_002442555.1'},
#  'GCF_000204295.1': {'name': 'GCF_000204295.1'},
#  'GCF_017798225.1': {'name': 'GCF_017798225.1'},
#  'GCF_021029445.1': {'name': 'GCF_021029445.1'},
#  'GCF_002941105.1': {'name': 'GCF_002941105.1'},
#  'GCF_002741095.1': {'name': 'GCF_002741095.1'},
#  'GCF_900106015.1': {'name': 'GCF_900106015.1'},
#  'GCF_000319815.1': {'name': 'GCF_000319815.1'},
#  'GCF_015712065.1': {'name': 'GCF_015712065.1'},
#  'GCF_013409125.2': {'name': 'GCF_013409125.2'},
#  'GCF_016861485.1': {'name': 'GCF_016861485.1'},
#  'GCF_021654315.1': {'name': 'GCF_021654315.1'},
#  'GCF_013200955.1': {'name': 'GCF_013200955.1'},
#  'GCF_000017205.1': {'name': 'GCF_000017205.1'},
#  'GCF_011466835.1': {'name': 'GCF_011466835.1'},
#  'GCF_000006765.1': {'name': 'GCF_000006765.1'},
#  'GCA_000014625.1': {'name': 'GCA_000014625.1'},
#  'GCF_000026645.1': {'name': 'GCF_000026645.1'},
#  'GCF_000568855.2': {'name': 'GCF_000568855.2'},
#  'GCF_012971725.1': {'name': 'GCF_012971725.1'},
#  'GCF_900188285.1': {'name': 'GCF_900188285.1'},
#  'GCF_000349845.1': {'name': 'GCF_000349845.1'},
#  'GCF_004745455.1': {'name': 'GCF_004745455.1'},
#  'GCF_009911755.1': {'name': 'GCF_009911755.1'},
#  'GCF_001708505.1': {'name': 'GCF_001708505.1'},
#  'GCF_013393345.1': {'name': 'GCF_013393345.1'},
#  'GCF_020422905.1': {'name': 'GCF_020422905.1'},
#  'GCF_021605025.1': {'name': 'GCF_021605025.1'},
#  'GCF_019879085.1': {'name': 'GCF_019879085.1'},
#  'GCF_011397855.1': {'name': 'GCF_011397855.1'},
#  'GCF_900105995.1': {'name': 'GCF_900105995.1'},
#  'GCF_900105885.1': {'name': 'GCF_900105885.1'},
#  'GCF_900104805.1': {'name': 'GCF_900104805.1'},
#  'GCF_001518815.1': {'name': 'GCF_001518815.1'},
#  'GCF_014522265.1': {'name': 'GCF_014522265.1'},
#  'GCF_008693965.1': {'name': 'GCF_008693965.1'},
#  'GCF_900105255.1': {'name': 'GCF_900105255.1'},
#  'GCF_900105005.1': {'name': 'GCF_900105005.1'},
#  'GCF_900104945.1': {'name': 'GCF_900104945.1'},
#  'GCF_020025155.1': {'name': 'GCF_020025155.1'},
#  'GCF_009497895.1': {'name': 'GCF_009497895.1'},
#  'GCF_900105655.1': {'name': 'GCF_900105655.1'},
#  'GCF_002362295.1': {'name': 'GCF_002362295.1'},
#  'GCF_000046845.1': {'name': 'GCF_000046845.1'},
#  'GCF_005281455.1': {'name': 'GCF_005281455.1'},
#  'GCA_001077675.1': {'name': 'GCA_001077675.1'},
#  'GCF_001682515.1': {'name': 'GCF_001682515.1'},
#  'GCF_000413935.1': {'name': 'GCF_000413935.1'},
#  'GCF_024448735.1': {'name': 'GCF_024448735.1'},
#  'GCF_009740185.1': {'name': 'GCF_009740185.1'},
#  'GCF_021432765.1': {'name': 'GCF_021432765.1'},
#  'GCF_000327065.1': {'name': 'GCF_000327065.1'},
#  'GCF_000825645.2': {'name': 'GCF_000825645.2'},
#  'GCF_900636845.1': {'name': 'GCF_900636845.1'},
#  'GCF_000219605.1': {'name': 'GCF_000219605.1'},
#  'GCF_000013785.1': {'name': 'GCF_000013785.1'},
#  'GCF_000696345.2': {'name': 'GCF_000696345.2'},
#  'GCF_000746525.1': {'name': 'GCF_000746525.1'},
#  'GCF_009755645.1': {'name': 'GCF_009755645.1'},
#  'GCF_021601925.1': {'name': 'GCF_021601925.1'},
#  'GCF_000759535.1': {'name': 'GCF_000759535.1'},
#  'GCF_003940825.1': {'name': 'GCF_003940825.1'},
#  'GCF_014268885.2': {'name': 'GCF_014268885.2'},
#  'GCF_019139535.1': {'name': 'GCF_019139535.1'},
#  'GCF_019139675.1': {'name': 'GCF_019139675.1'},
#  'GCF_002884415.1': {'name': 'GCF_002884415.1'},
#  'GCF_000026105.1': {'name': 'GCF_000026105.1'},
#  'GCF_023277925.1': {'name': 'GCF_023277925.1'},
#  'GCF_002736065.1': {'name': 'GCF_002736065.1'},
#  'GCF_001515585.1': {'name': 'GCF_001515585.1'},
#  'GCF_019139895.1': {'name': 'GCF_019139895.1'},
#  'GCF_019139835.1': {'name': 'GCF_019139835.1'},
#  'GCF_014269025.1': {'name': 'GCF_014269025.1'},
#  'GCF_005080685.1': {'name': 'GCF_005080685.1'},
#  'GCF_024023035.1': {'name': 'GCF_024023035.1'},
#  'GCF_021725455.1': {'name': 'GCF_021725455.1'},
#  'GCF_001477425.1': {'name': 'GCF_001477425.1'},
#  'GCF_002688705.1': {'name': 'GCF_002688705.1'},
#  'GCF_017166425.1': {'name': 'GCF_017166425.1'},
#  'GCF_013425825.1': {'name': 'GCF_013425825.1'},
#  'GCF_001655295.1': {'name': 'GCF_001655295.1'},
#  'GCF_007833495.1': {'name': 'GCF_007833495.1'},
#  'GCF_014269225.2': {'name': 'GCF_014269225.2'},
#  'GCF_022049085.1': {'name': 'GCF_022049085.1'},
#  'GCF_014656565.1': {'name': 'GCF_014656565.1'},
#  'GCF_000510285.1': {'name': 'GCF_000510285.1'},
#  'GCF_002864795.1': {'name': 'GCF_002864795.1'},
#  'GCF_001020725.2': {'name': 'GCF_001020725.2'},
#  'GCF_900475285.1': {'name': 'GCF_900475285.1'},
#  'GCF_015476275.1': {'name': 'GCF_015476275.1'},
#  'GCF_011040435.1': {'name': 'GCF_011040435.1'},
#  'GCF_000280575.1': {'name': 'GCF_000280575.1'},
#  'GCF_014268755.2': {'name': 'GCF_014268755.2'},
#  'GCF_001543125.1': {'name': 'GCF_001543125.1'},
#  'GCF_013403585.1': {'name': 'GCF_013403585.1'},
#  'GCF_900106045.1': {'name': 'GCF_900106045.1'},
#  'GCF_014268455.2': {'name': 'GCF_014268455.2'},
#  'GCF_003626995.1': {'name': 'GCF_003626995.1'},
#  'GCF_001641345.1': {'name': 'GCF_001641345.1'},
#  'GCF_001647715.1': {'name': 'GCF_001647715.1'},
#  'GCF_900475215.1': {'name': 'GCF_900475215.1'},
#  'GCF_004124255.1': {'name': 'GCF_004124255.1'},
#  'GCF_022870785.1': {'name': 'GCF_022870785.1'},
#  'GCF_019285655.1': {'name': 'GCF_019285655.1'},
#  'GCF_014268375.2': {'name': 'GCF_014268375.2'},
#  'GCF_001297075.1': {'name': 'GCF_001297075.1'},
#  'GCF_003852025.1': {'name': 'GCF_003852025.1'},
#  'GCF_901482615.1': {'name': 'GCF_901482615.1'},
#  'GCF_900625045.1': {'name': 'GCF_900625045.1'},
#  'GCF_021233455.1': {'name': 'GCF_021233455.1'},
#  'GCF_014268275.2': {'name': 'GCF_014268275.2'},
#  'GCF_001730655.1': {'name': 'GCF_001730655.1'},
#  'GCF_018417575.1': {'name': 'GCF_018417575.1'},
#  'GCF_002980135.1': {'name': 'GCF_002980135.1'},
#  'GCF_016134935.1': {'name': 'GCF_016134935.1'},
#  'GCF_002007785.1': {'name': 'GCF_002007785.1'},
#  'GCF_022533565.1': {'name': 'GCF_022533565.1'},
#  'GCF_008801565.1': {'name': 'GCF_008801565.1'},
#  'GCF_000009225.2': {'name': 'GCF_000009225.2'},
#  'GCF_002966835.1': {'name': 'GCF_002966835.1'},
#  'GCF_013778535.1': {'name': 'GCF_013778535.1'},
#  'GCF_900601635.1': {'name': 'GCF_900601635.1'},
#  'GCF_019139815.1': {'name': 'GCF_019139815.1'},
#  'GCF_900104915.1': {'name': 'GCF_900104915.1'},
#  'GCF_022807995.1': {'name': 'GCF_022807995.1'},
#  'GCF_019139855.1': {'name': 'GCF_019139855.1'},
#  'GCF_001547915.1': {'name': 'GCF_001547915.1'},
#  'GCF_001547895.1': {'name': 'GCF_001547895.1'},
#  'GCF_000828695.1': {'name': 'GCF_000828695.1'},
#  'GCF_000012265.1': {'name': 'GCF_000012265.1'},
#  'GCF_000397205.1': {'name': 'GCF_000397205.1'},
#  'GCF_009362955.1': {'name': 'GCF_009362955.1'},
#  'GCF_003851145.1': {'name': 'GCF_003851145.1'},
#  'GCF_003851985.1': {'name': 'GCF_003851985.1'},
#  'GCF_003851385.1': {'name': 'GCF_003851385.1'},
#  'GCF_000813225.1': {'name': 'GCF_000813225.1'},
#  'GCF_000237045.1': {'name': 'GCF_000237045.1'},
#  'GCF_020424105.1': {'name': 'GCF_020424105.1'},
#  'GCF_900636995.1': {'name': 'GCF_900636995.1'},
#  'GCF_003850425.1': {'name': 'GCF_003850425.1'},
#  'GCF_003850385.1': {'name': 'GCF_003850385.1'},
#  'GCF_014076455.1': {'name': 'GCF_014076455.1'},
#  'GCF_001708425.1': {'name': 'GCF_001708425.1'},
#  'GCF_001412045.1': {'name': 'GCF_001412045.1'},
#  'GCF_019141525.1': {'name': 'GCF_019141525.1'},
#  'GCF_003410335.1': {'name': 'GCF_003410335.1'},
#  'GCF_013347965.1': {'name': 'GCF_013347965.1'},
#  'GCF_001269655.1': {'name': 'GCF_001269655.1'},
#  'GCF_014268695.2': {'name': 'GCF_014268695.2'},
#  'GCF_008370715.1': {'name': 'GCF_008370715.1'},
#  'GCF_000194805.1': {'name': 'GCF_000194805.1'},
#  'GCF_001449085.1': {'name': 'GCF_001449085.1'},
#  'GCF_021389915.1': {'name': 'GCF_021389915.1'},
#  'GCF_008801455.1': {'name': 'GCF_008801455.1'},
#  'GCF_002356535.2': {'name': 'GCF_002356535.2'},
#  'GCF_019139795.1': {'name': 'GCF_019139795.1'},
#  'GCF_004348895.1': {'name': 'GCF_004348895.1'},
#  'GCF_001661075.1': {'name': 'GCF_001661075.1'},
#  'GCF_000293885.2': {'name': 'GCF_000293885.2'},
#  'GCF_003671865.1': {'name': 'GCF_003671865.1'},
#  'GCF_004135995.1': {'name': 'GCF_004135995.1'},
#  'GCF_019693255.1': {'name': 'GCF_019693255.1'},
#  'GCF_002091695.1': {'name': 'GCF_002091695.1'},
#  'GCF_001042905.1': {'name': 'GCF_001042905.1'},
#  'GCF_001655615.1': {'name': 'GCF_001655615.1'},
#  'GCF_002355315.1': {'name': 'GCF_002355315.1'},
#  'GCF_014190825.1': {'name': 'GCF_014190825.1'},
#  'GCF_014863605.1': {'name': 'GCF_014863605.1'},
#  'GCF_021398855.1': {'name': 'GCF_021398855.1'},
#  'GCF_019719375.1': {'name': 'GCF_019719375.1'},
#  'GCF_001594225.1': {'name': 'GCF_001594225.1'},
#  'GCF_001655595.1': {'name': 'GCF_001655595.1'},
#  'GCF_014863585.1': {'name': 'GCF_014863585.1'},
#  'GCF_014268495.1': {'name': 'GCF_014268495.1'},
#  'GCF_004683905.1': {'name': 'GCF_004683905.1'},
#  'GCF_002287865.1': {'name': 'GCF_002287865.1'},
#  'GCF_014268445.1': {'name': 'GCF_014268445.1'},
#  'GCF_014268485.2': {'name': 'GCF_014268485.2'},
#  'GCF_019614655.1': {'name': 'GCF_019614655.1'},
#  'GCF_014268595.1': {'name': 'GCF_014268595.1'},
#  'GCF_017167965.1': {'name': 'GCF_017167965.1'},
#  'GCF_001605965.1': {'name': 'GCF_001605965.1'},
#  'GCF_014268585.2': {'name': 'GCF_014268585.2'},
#  'GCF_024072295.1': {'name': 'GCF_024072295.1'},
#  'GCF_900105485.1': {'name': 'GCF_900105485.1'}}

# %%
def get_hover_text(tree):
    """return a list of f strings for plotly hoverdata that correspond to each node on the tree.
    
    Note: Terminal nodes will not be annotated beyond what is input in the clade.name field.

    """
        
    with open('./data/summary_data/internal_node_dict.json', 'r') as f:
        int_node_dict = json.load(f)
    text=[]
    my_clades = tree.depths().keys()
    for node in my_clades:
        if node.is_terminal():
            text.append(node.name)
        else:
            text_dict = int_node_dict.get(node.name)
            taxid = text_dict["taxid"]
            sci_name = text_dict["sci_name"]
            rank = text_dict["rank"]
            data =  (f'name: {node.name}<br>'
                    f'sci_name: {sci_name}<br>'
                    f'rank: {rank}<br>'        
                    f'taxid: {taxid}<br>'
                )
            text.append(data)
    return text

text = get_hover_text(tree)

# %%
t=[{'prop_id': 'copynumber_bargraph.clickData', 'value': {'points': [{'curveNumber': 0, 'pointNumber': 116, 'pointIndex': 116, 'x': 0.0834335, 'y': 66.12944335937499, 'text': 'name: N30<br>sci_name: Bacteria<br>rank: superkingdom<br>taxid: 2<br>', 'marker.size': 6, 'marker.color': 'rgb(25,25,25)', 'bbox': {'x0': 538.77, 'x1': 544.77, 'y0': 609.8299999999999, 'y1': 615.8299999999999}}]}}, {'prop_id': 'name_drpdwn_keyword.value', 'value': 'GCF_001647695.1'}]
t[0]['prop_id']
# Out:
# 'copynumber_bargraph.clickData'

# %%
mrca_clades
options = [{'label':name,'value':cl_obj} for name, cl_obj in mrca_clades.items()]

# %%
mrca_clades = get_anc_node_each_rank(tree, rank='phylum', path_to_summary = path_to_summary)
cl_to_highlight = mrca_clades['Pseudomonadota']
cl_to_highlight
# Out:
# 'N0'

# %%
fig = jdt.create_tree(tree, hover_text = text)#, cl_to_highlight=cl_to_highlight)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig = jdt.create_tree(tree, hover_text = text)#, cl_to_highlight=cl_to_highlight)
#
# TypeError: create_tree() got an unexpected keyword argument 'hover_text'

# %%
go.Figure(fig)
